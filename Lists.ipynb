# %%
# Make a list of Actors and Actresses
actors=["Salman Khan","Ranbir Kapoor","Ranveer Singh"]

# Check the type of Actors
type(actors)
# Out:
# list

# %%
# Another way to create the list using functions
actress=list(["Katrina","Kareena","Sara"])
type(actress)
# Out:
# list

# %%
# Make a list of 1,2,3,4,80

list_numbers=[1,2,3,4,80]
item_index_3=list_numbers[3]
item_index_neg=list_numbers[-1]
print("Item at index 3 is:",item_index_3)
print("Item at index 3 is:",item_index_neg)
# Out:
# Item at index 3 is: 4
# Item at index 3 is: 80

# %%
# Slicing of the list

list_numbers=[1,2,3,4,80]
sl1=list_numbers[1:4]
sl2=list_numbers[2:5]
sl3=list_numbers[1:4]
sl4=list_numbers[ : ]
sl5=list_numbers[1: ]
sl6=list_numbers[ :4]
print(sl1,sl2,sl3,sl4,sl5,sl6)
# Out:
# [2, 3, 4] [3, 4, 80] [2, 3, 4] [1, 2, 3, 4, 80] [2, 3, 4, 80] [1, 2, 3, 4]
