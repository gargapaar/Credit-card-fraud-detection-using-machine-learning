# %%
# Outer Join
# Return all the rows from both tables, join the records from
# the Left table which have matching keys in the right table
pd.merge(df1,df2,on='customer_id',how='outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c32a8b14c06b> in <module>()
# ----> 1 pd.merge(df1,df2,on='customer_id',how='outer')
#
# NameError: name 'pd' is not defined

# %%
pd.merge(df1,df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-01b6d59980d6> in <module>()
# ----> 1 pd.merge(df1,df2)
#
# NameError: name 'pd' is not defined

# %%
# Handling Missing Values
#
