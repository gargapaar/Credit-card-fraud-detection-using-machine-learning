# %%
df[['customer zervice calls''churn']].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b3f5fdd5a8eb> in <module>()
# ----> 1 df[['customer zervice calls''churn']].head(10)
#
# NameError: name 'df' is not defined
