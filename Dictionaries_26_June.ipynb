# %%
# Create an Empty Dictionary
mydict={}
type(mydict)
# Out:
# dict

# %%
mydict1={"name":"devanshu"}
mydict1

dict(name="devanshu",mobile="9871000000")
# Out:
# {'mobile': '9871000000', 'name': 'devanshu'}

# %%
# %time{"name":"Apaar"}
# %time dict(name="Apaar")
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.39 µs
# CPU times: user 47 µs, sys: 11 µs, total: 58 µs
# Wall time: 60.6 µs
# {'name': 'Apaar'}

# %%
# Bollywood Dictionary
movies=['Kabir Singh','Bharat']
Actors=['Shahid','Salman']
Actress=['Kiara','Katrina']

Bollywood={"Movies":movies,"Actors":Actors,"Actress":Actress}
Bollywood
# Out:
# {'Actors': ['Shahid', 'Salman'],
#  'Actress': ['Kiara', 'Katrina'],
#  'Movies': ['Kabir Singh', 'Bharat']}

# %%
# Access the list of keys
list(Bollywood)
# Out:
# ['Movies', 'Actors', 'Actress']

# %%
# Access the value using keys in dictionary
#Bollywood['movies']


#Extract all values from dictionary
#for key in list(Bollywood):
#  print(Bollywood[key])

# %%
#Bollywood["flops"]-["himmatwala","race3"]
#Bollywood
